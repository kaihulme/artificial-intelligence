# %% [markdown]
# # Multiagent Systems - Covid-19 Simulation
#
# - Before starting, make sure you have installed Mesa
# - You could install via command line --- pip install mesa
# - For generating plots, you will need matplotlib which too you can install via command line --- pip install matplotlib

# %%
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector
import matplotlib.pyplot as plt

# %% [markdown]
# ### Simulation parameters:

# %%
NUM_OF_AGENTS = 1000

# PLACES
PARK = 0
HOME = 1
GROCERY = 2
QC = 3 # Quarantine center

# INFECTION STATES
NOT_INFECTED = 0
INFECTED_A = 1
INFECTED_S = 2
CRITICAL = 3
CURED = 4
DECEASED = 5

# Capacity of quarantine center
QC_LIMIT = 100 # Capacity of quarantine center

# %% [markdown]
# ### Human (agent) class:

# %%
class HumanAgent(Agent):
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.homeId = unique_id//4
        self.health = NOT_INFECTED

    def step(self):
        self.updateHealth()
        self.move()

    # Function for mobility pattern modeling
    def move(self):
        x, y = self.pos
        if x==QC:
            return
        if self.model.quarantine and self.model.QC_Occupancy < QC_LIMIT and self.health == CRITICAL:
            self.model.grid.move_agent(self, (QC,0))
            self.model.QC_Occupancy += 1
            return
        if self.model.quarantine and self.model.QC_Occupancy < QC_LIMIT and self.health == INFECTED_S and self.random.uniform(0, 1) <= 0.20:
            self.model.grid.move_agent(self, (QC,0))
            self.model.QC_Occupancy += 1
            return
        if x == HOME:
          p = self.random.uniform(0, 1)
          # Visit park with 10% probability
          if p <= 0.1:
            newX = PARK
            newY = self.random.choice((0,1)) # Visit one of the two parks
          # Visit grocery store with 20% probability
          elif p <= 0.3:
            newX = GROCERY
            newY = self.random.choice((0,1,2,3,4)) # Visit one of the five grocery stores
          else:
            newX = x
            newY = y
        if x == GROCERY or x == PARK: # If grocery or park, return home
          newX = HOME
          newY = self.homeId
        self.model.grid.move_agent(self, (newX,newY))

    # Function for modeling the spread of the virus
    def updateHealth(self):
        p = self.random.uniform(0, 1)
        if self.health == INFECTED_A and p > 0.75:
                self.health += 1
        elif self.health == INFECTED_S:
            if p > 0.75 and p <= 0.85:
                self.health += 1
            elif p > 0.85:
                self.health = CURED
                x,y = self.pos
                if x == QC:
                    self.model.QC_Occupancy -= 1                
        elif self.health == CRITICAL:
            if p > 0.75 and p <= 0.95:
                self.health += 1
                x,y = self.pos
                if x == QC:
                    self.model.QC_Occupancy -= 1
            elif p > 0.95:
                self.health = DECEASED
                self.model.deceasedCount += 1
                x,y = self.pos
                if x == QC:
                    self.model.QC_Occupancy -= 1
        return
    
    def infect(self):
        p = self.random.uniform(0, 1)
        if self.health == NOT_INFECTED and p > self.model.p0b:
                self.health += 1

# %% [markdown]
# ### Method to compute number of infected agents:

# %%
def compute_infected(model):
    infectedAgents = [agent for agent in model.schedule.agents if agent.health in (INFECTED_A, INFECTED_S, CRITICAL) ]
    return len(infectedAgents)

# %% [markdown]
# ### Covid-19 (model) class:

# %%
class CovidModel(Model):
    """A model with some number of agents."""
    def __init__(self, N, startingState, quarantine = False, socialDistancing = False):
        self.num_agents = N
        # self.random.seed(42)
        self.QC_Occupancy = 0
        self.deceasedCount = 0
        self.quarantine = quarantine
        self.grid = MultiGrid(4 if quarantine else 3, 250, False)
        self.schedule = RandomActivation(self)
        self.running = True
        
        # With socialdistancing the probability of infection is 10% (p0b = 0.9) otherwise it is 50%
        self.p0b = 0.5
        if socialDistancing:
            self.p0b = 0.9
        
        # Create agents
        for i in range(self.num_agents):
            a = HumanAgent(i, self)
            self.schedule.add(a)
            self.grid.place_agent(a, (HOME, a.homeId))
        for a in self.random.sample(self.schedule.agents,int(startingState*N)):
            a.health = INFECTED_A
        self.datacollector = DataCollector(
            model_reporters={"Infected": compute_infected,
                             "QC_Occupancy": "QC_Occupancy"}
            )
    def step(self):
        self.datacollector.collect(self)
        '''Advance the model by one step.'''
        self.schedule.step()
        self.identifyAgentsAndUpdateSpread()
    def identifyAgentsAndUpdateSpread(self):
        # Park
        for y in range(2):
            agents = self.grid.get_cell_list_contents([(PARK,y)])
            self.updateSpread(agents)
        # Grocery
        for y in range(5):
            agents = self.grid.get_cell_list_contents([(GROCERY,y)])
            self.updateSpread(agents)
        # Home
        for y in range(250):
            agents = self.grid.get_cell_list_contents([(HOME,y)])
            self.updateSpread(agents)
    def updateSpread(self, agents):
        if any(a.health in (INFECTED_A, INFECTED_S, CRITICAL) for a in agents):
            [a.infect() for a in agents]

# %% [markdown]
# ### Run simulation method:

# %%
def runSimulation(startingState,quarantine=False,socialDistancing=False):
    modelInst = CovidModel(NUM_OF_AGENTS, startingState, quarantine, socialDistancing)
    i=0
    while any(a.health in (INFECTED_A, INFECTED_S, CRITICAL) for a in modelInst.schedule.agents):
        i += 1
        modelInst.step()
    modelDF = modelInst.datacollector.get_model_vars_dataframe()
    
    return i, modelInst.deceasedCount, modelDF.QC_Occupancy,modelDF.Infected

# %% [markdown]
# ### Plot simulation method:

# %%
def plot_simulation(state, q, d, plotQC=False, labelState=True):
    averageDays = 0
    dayWithMaxInfectionRate = 0
    maxInfection = 0
    averageCasualties = 0
    for i in range(10):
        days, Casualties, QC_Occupancy, Infected = runSimulation(state,q,d)
        averageDays+=days
        dayWithMaxInfectionRate+=Infected.idxmax()
        maxInfection += Infected.max()
        averageCasualties += Casualties
        if i == 9:
            Infected.plot(legend=True, label=f"inf (s={state}, q={q}, sd={d})")
            if (plotQC):
                QC_Occupancy.plot(legend=True, label=f"qc (q={q}, d={d})")
    print('Average number of days before stabilization: ' + str(averageDays/10))
    print('Average of the Day with peak Infection ('+str(maxInfection/10)+'): ' + str(dayWithMaxInfectionRate/10))
    print('Average Number of Casualties: ' + str(averageCasualties/10))

# %% [markdown]
# ### Baseline 1
# - StartingState = 10%
# - Quarantine=False
# - Social Distancing=False
#
# ### Baseline 2
# - StartingState = 25%
# - Quarantine=False
# - Social Distancing=False
#
# ### Baseline 3
# - StartingState = 50%
# - Quarantine=False
# - Social Distancing=False

# %%
starting_states = [0.1, 0.25, 0.5]
quarantine = False
socialDistancing = False

for state in starting_states:
    print(f"\nState: {state}")
    plot_simulation(state, quarantine, socialDistancing)
# Out:
# State: 0.1
# Average number of days before stabilization: 44.9
# Average of the Day with peak Infection (775.0): 5.3
# Average Number of Casualties: 79.1
#
# State: 0.25
# Average number of days before stabilization: 43.9
# Average of the Day with peak Infection (788.7): 4.2
# Average Number of Casualties: 78.6
#
# State: 0.5
# Average number of days before stabilization: 41.3
# Average of the Day with peak Infection (842.9): 3.2
# Average Number of Casualties: 82.8

# %% [markdown]
# ### Adding Quarantine Centers
# Enable quarantine centers for each baseline and see how the plots change
# In the line plot, include a plot for capacity of qurantine center too

# %%
starting_states = [0.1, 0.25, 0.5]
quarantine = True
socialDistancing = False

for state in starting_states:
    print(f"\nStart state: {state}")
    plot_simulation(state, quarantine, socialDistancing, plotQC=True)
# Out:
# Start state: 0.1
# Average number of days before stabilization: 45.4
# Average of the Day with peak Infection (767.1): 5.4
# Average Number of Casualties: 76.5
#
# Start state: 0.25
# Average number of days before stabilization: 42.7
# Average of the Day with peak Infection (792.3): 4.4
# Average Number of Casualties: 78.7
#
# Start state: 0.5
# Average number of days before stabilization: 43.6
# Average of the Day with peak Infection (842.8): 3.2
# Average Number of Casualties: 84.4

# %% [markdown]
# ### Enabling Social Distancing Norms
# Enable social distancing norms in addition to quaratine centers for each baseline and see how the plots change
# In the line plot, include a plot for capacity of qurantine center too

# %%
starting_states = [0.1, 0.25, 0.5]
quarantine = True
socialDistancing = True

for state in starting_states:
    print(f"\nStart state: {state}")
    plot_simulation(state, quarantine, socialDistancing, plotQC=True)
# Out:
# Start state: 0.1
# Average number of days before stabilization: 95.4
# Average of the Day with peak Infection (257.4): 8.2
# Average Number of Casualties: 69.8
#
# Start state: 0.25
# Average number of days before stabilization: 82.3
# Average of the Day with peak Infection (359.6): 4.8
# Average Number of Casualties: 68.5
#
# Start state: 0.5
# Average number of days before stabilization: 72.1
# Average of the Day with peak Infection (557.7): 2.6
# Average Number of Casualties: 68.3

# %% [markdown]
# ### Comparison
#
# Comparison between different measures (all starting at 10% infection)

# %%
measures = [[0.1, False, False],
            [0.1, True,  False],
            [0.1, True,  True ]]

for (state, q, d) in measures:
    print(f"\nQuarantine: {q}, Social Distancing: {d}")
    if q:
        plot_simulation(state, q, d, plotQC=True)
    else:
        plot_simulation(state, q, d)
# Out:
# Quarantine: False, Social Distancing: False
# Average number of days before stabilization: 41.7
# Average of the Day with peak Infection (775.3): 5.2
# Average Number of Casualties: 80.0
#
# Quarantine: True, Social Distancing: False
# Average number of days before stabilization: 42.4
# Average of the Day with peak Infection (767.3): 5.1
# Average Number of Casualties: 79.0
#
# Quarantine: True, Social Distancing: True
# Average number of days before stabilization: 93.3
# Average of the Day with peak Infection (273.4): 8.9
# Average Number of Casualties: 68.6

# %% [markdown]
# This shows social distancing measures are most effective and a quarantine capacity of 100 does little.

# %%
measures = [[0.1, False, False],
            [0.1, True,  False],
            [0.1, True,  True ]]

for (state, q, d) in measures:
    print(f"\nQuarantine: {q}, Social Distancing: {d}")
    if q:
        plot_simulation(state, q, d, plotQC=True)
    else:
        plot_simulation(state, q, d)
